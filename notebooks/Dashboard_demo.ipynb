# %%
# !pip install -e ..
# Out:
# Obtaining file:///C:/Users/admin/git/pds21
# ...
#   Attempting uninstall: yellowcab
#     Found existing installation: yellowcab 0.0.1.dev1
#     Uninstalling yellowcab-0.0.1.dev1:
#       Successfully uninstalled yellowcab-0.0.1.dev1
#   Running setup.py develop for yellowcab
# ...
#       WARNING: Cannot remove entries from nonexistent file c:\users\admin\miniconda3\envs\pds21\lib\site-packages\easy-install.pth

# %%
from yellowcab.io.input import read_parquet_dataset
from yellowcab.eda.dashboard import create_dashboard
from yellowcab.eda.dashboard import create_animated_monthly_plot
import panel as pn
pn.extension()

# %%
#Adjust the path before running
cab_df = read_parquet_dataset(relative_path="input/trip_data")

# %%
#Runs the dashboard on a local Bokeh server
create_dashboard(df=cab_df).show()
# Out:
# Launching server at http://localhost:50820

# %%
#create_animated_monthly_plot(df=cab_df,aspect='dropoff')
